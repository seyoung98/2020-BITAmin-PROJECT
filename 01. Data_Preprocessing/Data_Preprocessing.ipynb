# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
data=pd.read_csv('c:/Bit_data/FIFA.csv',index_col=0)
data
# Out:
#            ID                Name  Age  \
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 3      193080              De Gea   27
# 4      192985        K. De Bruyne   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18207 entries, 0 to 18206
# Data columns (total 88 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Photo                     18207 non-null  object
#  4   Nationality               18207 non-null  object
#  5   Flag                      18207 non-null  object
#  6   Overall                   18207 non-null  int64
#  7   Potential                 18207 non-null  int64
#  8   Club                      17966 non-null  object
#  9   Club Logo                 18207 non-null  object
#  10  Value                     18207 non-null  object
#  11  Wage                      18207 non-null  object
#  12  Special                   18207 non-null  int64
# ...

# %% [markdown]
# ## 1. 사용 안할 열,  행 삭제

# %%
data.drop(['ID', 'Photo', 'Flag', 'Club Logo', 'Real Face'], axis=1, inplace=True)
data
# Out:
#                      Name  Age Nationality  Overall  Potential  \
# 0                L. Messi   31   Argentina       94         94
# 1       Cristiano Ronaldo   33    Portugal       94         94
# 2               Neymar Jr   26      Brazil       92         93
# 3                  De Gea   27       Spain       91         93
# 4            K. De Bruyne   27     Belgium       91         92
# ...                   ...  ...         ...      ...        ...
# 18202        J. Lundstram   19     England       47         65
# 18203  N. Christoffersson   19      Sweden       47         63
# 18204           B. Worman   16     England       47         67
# 18205      D. Walker-Rice   17     England       47         66
# 18206           G. Nugent   16     England       46         66
#
#                       Club    Value   Wage  Special Preferred Foot  ...  \
# 0             FC Barcelona  €110.5M  €565K     2202           Left  ...
# ...

# %%
# null 값이 너무 많았던 'Laded From' 열 삭제
data.drop(['Loaned From'], axis=1, inplace=True)

# %% [markdown]
# ## 2. 능력치 정제

# %%
data_stats=data.loc[:, 'LS':'RB']

stats=data_stats.columns

for i in range(len(data)):
    if data_stats.loc[i].isnull().sum() != 0:
        continue
    for stat in stats:
        data.loc[i, stat]=eval(data.loc[i, stat])

# %% [markdown]
# ## 3. 결측 행삭제

# %%
# Preferred Foot 부터 Relase Clause까지 데이터 없는 48명 데이터 삭제

# %%
data.iloc[13236:13283, :]
# Out:
#                  Name  Age       Nationality  Overall  Potential  \
# 13236      J. McNulty   33          Scotland       62         62
# 13237      J. Barrera   29         Nicaragua       62         62
# 13238        J. Stead   35           England       62         62
# 13239     A. Semprini   20             Italy       62         72
# 13240      R. Bingham   24           England       62         66
# 13241    K. Dankowski   21            Poland       62         72
# 13242       I. Colman   23         Argentina       62         70
# 13243       M. Feeney   19           England       62         78
# 13244        R. Minor   30           Denmark       62         62
# 13245          Klauss   21            Brazil       62         69
# 13246      I. Sissoko   22            France       62         68
# 13247         F. Hart   28           Austria       62         62
# 13248   L. McCullough   24  Northern Ireland       62         69
# ...

# %%
data = data.dropna(subset=['Preferred Foot'],how='any', axis=0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18159 entries, 0 to 18206
# Data columns (total 82 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      18159 non-null  object
#  1   Age                       18159 non-null  int64
#  2   Nationality               18159 non-null  object
#  3   Overall                   18159 non-null  int64
#  4   Potential                 18159 non-null  int64
#  5   Club                      17918 non-null  object
#  6   Value                     18159 non-null  object
#  7   Wage                      18159 non-null  object
#  8   Special                   18159 non-null  int64
#  9   Preferred Foot            18159 non-null  object
#  10  International Reputation  18159 non-null  float64
#  11  Weak Foot                 18159 non-null  float64
#  12  Skill Moves               18159 non-null  float64
# ...

# %% [markdown]
# ## 4. 단위 환산

# %%
# feet to cm
data['Height'] = data['Height'].str.replace('\'', '.')
data['Height'].fillna(0, inplace=True)
data['Height'] = data['Height'].astype(float) * 30.84

# %%
data['Height'].round(2)
# Out:
# 0        175.79
# 1        191.21
# 2        181.96
# 3        197.38
# 4        157.59
#           ...
# 18202    181.96
# 18203    194.29
# 18204    178.87
# 18205    157.28
# 18206    157.28
# Name: Height, Length: 18159, dtype: float64

# %%
#lbs to kg
data['Weight'] = data['Weight'].str.replace('lbs', '')
data['Weight'].fillna(0, inplace=True)
data['Weight'] = data['Weight'].astype(float) / 2.205

# %%
data['Weight'].round(2)
# Out:
# 0        72.11
# 1        82.99
# 2        68.03
# 3        76.19
# 4        69.84
#          ...
# 18202    60.77
# 18203    77.10
# 18204    67.12
# 18205    69.84
# 18206    79.82
# Name: Weight, Length: 18159, dtype: float64

# %%
# 돈 단위 통일 ( 유로 -> 달러)

# %%
data['Value']
# Out:
# 0        €110.5M
# 1           €77M
# 2        €118.5M
# 3           €72M
# 4          €102M
#           ...
# 18202       €60K
# 18203       €60K
# 18204       €60K
# 18205       €60K
# 18206       €60K
# Name: Value, Length: 18159, dtype: object

# %%
def money(col):
    col=col.str.replace('€', '')
    c=col.str.split(pat=(r'([A-Z])'), expand=True)
    c.iloc[:][1].replace('M', 1000000, inplace=True)
    c.iloc[:][1].replace('K', 1000, inplace=True)
    c.fillna(0, inplace=True)
    c[0] = c[0].astype(float)
    c[2] = c[0] * c[1]
    col=c[2]*1.21
    return col.astype(int)

# %%
data['Value'] = money(data['Value'])
data['Wage'] = money(data['Wage'])
data['Release Clause'] = money(data['Release Clause'])

# %% [markdown]
# ## 5. 포지션 grouping

# %%
data['Position'].value_counts()
# Out:
# ST     2152
# GK     2025
# CB     1778
# CM     1394
# LB     1322
# RB     1291
# RM     1124
# LM     1095
# CAM     958
# CDM     948
# RCB     662
# LCB     648
# LCM     395
# RCM     391
# LW      381
# RW      370
# RDM     248
# LDM     243
# LS      207
# RS      203
# RWB      87
# LWB      78
# CF       74
# RAM      21
# LAM      21
# RF       16
# LF       15
# Name: Position, dtype: int64

# %%
def classify_position(x):
    if x in (['ST','LW','RW','LS','RS','CF','LF','RF']):
        return 'FW'
    elif x in(['CM','RM','LM','CAM','CDM','RCM','LCM','RDM','LDM','RAM','LAM']):
        return 'MD'
    elif x in(['CB','LB','RB','RCB','LCB','RWB','LWB']):
        return 'DF'
    else:
        return 'GK'
    
data['Position simplified'] = data['Position'].apply(classify_position)
data['Position simplified'].value_counts(dropna=False)
# Out:
# MD    6838
# DF    5866
# FW    3418
# GK    2037
# Name: Position simplified, dtype: int64

# %% [markdown]
# ## 6. 시계열 데이터 정제

# %%
data['Contract Valid Until']=pd.to_datetime(data['Contract Valid Until'])
data['Contract Valid Until']=data['Contract Valid Until'].dt.to_period(freq='A')
data['Contract Valid Until']
# Out:
# 0        2021
# 1        2022
# 2        2022
# 3        2020
# 4        2023
#          ...
# 18202    2019
# 18203    2020
# 18204    2021
# 18205    2019
# 18206    2019
# Name: Contract Valid Until, Length: 18159, dtype: period[A-DEC]
